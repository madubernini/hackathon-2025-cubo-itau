# %%
import copy
import uuid
import os
import botocore.exceptions
import random
import pandas as pd
import awswrangler as wr
import boto3
import json

# %%
glue = boto3.client('glue')
s3 = boto3.client('s3')
client = boto3.client("bedrock-runtime", region_name="us-west-2")

# %%
def listar_glue_jobs():
    paginator = glue.get_paginator('get_jobs')
    all_jobs = []

    for page in paginator.paginate():
        for job in page['Jobs']:
            job_info = {
                'name': job['Name'],
                'script_location': job['Command']['ScriptLocation'],
            }
            all_jobs.append(job_info)

    return all_jobs

# %%
jobs = listar_glue_jobs()

# %%
def clonar_e_alterar_glue_job(nome_origem, nome_destino, novo_codigo, pasta="scripts-novos"):
    job_response = glue.get_job(JobName=nome_origem)
    job_def = job_response['Job']
    
    script_location = job_def['Command']['ScriptLocation']
    if not script_location.startswith("s3://"):
        raise ValueError("ScriptLocation inválido.")
    
    _, _, bucket, *chave = script_location.split("/")
    chave_original = "/".join(chave)
    
    nome_arquivo = os.path.basename(chave_original)
    
    pasta_base = os.path.dirname(chave_original).rstrip("/")
    novo_arquivo = f"{nome_destino}"
    novo_caminho = f"{pasta_base}/{pasta}/{novo_arquivo}".replace("//", "/")[1:] + '.py'

    s3.put_object(
        Bucket=bucket,
        Key=novo_caminho,
        Body=novo_codigo.encode("utf-8")
    )
    
    campos_remover = [
        'Name', 'CreatedOn', 'LastModifiedOn', 'ExecutionProperty', 
        'MaxRetries', 'AllocatedCapacity', 'GlueVersion', 'Tags',
        'ExecutionClass', 'Timeout', 'JobBookmarkOption'
    ]
    for campo in campos_remover:
        job_def.pop(campo, None)

    job_def['Command']['ScriptLocation'] = 's3://' + f"{bucket}/{novo_caminho}".replace("//", "/")
    
    try:
        glue.create_job(Name=nome_destino, **job_def)
        acao = "criado"
    except glue.exceptions.IdempotentParameterMismatchException:
        glue.update_job(JobName=nome_destino, JobUpdate=job_def)
        acao = "atualizado"
    
    return {
        "novo_job": nome_destino,
        "script_s3": job_def['Command']['ScriptLocation'],
        "acao": acao
    }

# %%
def listar_subpastas(bucket):
    resposta = s3.list_objects_v2(Bucket=bucket, Delimiter='/')
    subpastas = [
        pasta['Prefix'].rstrip('/')
        for pasta in resposta.get('CommonPrefixes', [])
        if pasta['Prefix'].rstrip('/') != 'athena'
    ]
    return subpastas

# %%
def gerar_codigo_exemplo_com_logging(result):
    return random.choice(list(result.keys()))

# %%
def criar_jobs_para_subpastas(subpastas, bucket, job_template, numero_servicos=20):
    resultados = []
    with open("out.json", "r") as fp:
        result = json.load(fp)
        for subpasta in subpastas:
            for i in range(1, numero_servicos + 1):
                nome_novo_job = f"{subpasta}_servico{i}"
                novo_codigo = gerar_codigo_exemplo_com_logging(result)
                resultado = clonar_e_alterar_glue_job(
                    nome_origem=job_template,
                    nome_destino=nome_novo_job,
                    novo_codigo=novo_codigo,
                    pasta=subpasta
                )
                print(f"✅ Criado: {resultado['novo_job']} em {subpasta}")
                resultados.append(resultado)
    return resultados

# %%
def ler_scripts_dos_jobs(lista_jobs):
    resultados = []

    for job in lista_jobs:
        nome = job['name']
        caminho = job['script_location']

        caminho = caminho.replace("s3://", "")
        partes = caminho.split("/", 1)
        bucket = partes[0]
        chave = partes[1]

        resposta = s3.get_object(Bucket=bucket, Key=chave)
        conteudo = resposta['Body'].read().decode('utf-8')

        if nome == "template":
            continue

        if "_" in nome:
            area, nome_servico = nome.split("_", 1)
        else:
            area = "desconhecido"
            nome_servico = nome

        resultados.append({
            "area": area,
            "nome_servico": nome_servico,
            "codigo": conteudo
        })

    return resultados

# %%
bucket = 'costs-data-123'
subpastas = listar_subpastas(bucket)
print("Subpastas:", subpastas)
# Out:
# Subpastas: ['cartoes', 'financas', 'finops', 'pix', 'ti']

# %%
job_template = "template"
resultados = criar_jobs_para_subpastas(subpastas, bucket, job_template)
# Out:
# ✅ Criado: cartoes_servico1 em cartoes
# ✅ Criado: cartoes_servico2 em cartoes
# ✅ Criado: cartoes_servico3 em cartoes
# ✅ Criado: cartoes_servico4 em cartoes
# ✅ Criado: cartoes_servico5 em cartoes
# ✅ Criado: cartoes_servico6 em cartoes
# ✅ Criado: cartoes_servico7 em cartoes
# ✅ Criado: cartoes_servico8 em cartoes
# ✅ Criado: cartoes_servico9 em cartoes
# ✅ Criado: cartoes_servico10 em cartoes
# ✅ Criado: cartoes_servico11 em cartoes
# ✅ Criado: cartoes_servico12 em cartoes
# ✅ Criado: cartoes_servico13 em cartoes
# ✅ Criado: cartoes_servico14 em cartoes
# ✅ Criado: cartoes_servico15 em cartoes
# ✅ Criado: cartoes_servico16 em cartoes
# ✅ Criado: cartoes_servico17 em cartoes
# ✅ Criado: cartoes_servico18 em cartoes
# ✅ Criado: cartoes_servico19 em cartoes
# ✅ Criado: cartoes_servico20 em cartoes
# ✅ Criado: financas_servico1 em financas
# ✅ Criado: financas_servico2 em financas
# ✅ Criado: financas_servico3 em financas
# ✅ Criado: financas_servico4 em financas
# ✅ Criado: financas_servico5 em financas
# ✅ Criado: financas_servico6 em financas
# ✅ Criado: financas_servico7 em financas
# ✅ Criado: financas_servico8 em financas
# ✅ Criado: financas_servico9 em financas
# ✅ Criado: financas_servico10 em financas
# ✅ Criado: financas_servico11 em financas
# ✅ Criado: financas_servico12 em financas
# ✅ Criado: financas_servico13 em financas
# ✅ Criado: financas_servico14 em financas
# ✅ Criado: financas_servico15 em financas
# ✅ Criado: financas_servico16 em financas
# ✅ Criado: financas_servico17 em financas
# ✅ Criado: financas_servico18 em financas
# ✅ Criado: financas_servico19 em financas
# ✅ Criado: financas_servico20 em financas
# ✅ Criado: finops_servico1 em finops
# ✅ Criado: finops_servico2 em finops
# ✅ Criado: finops_servico3 em finops
# ✅ Criado: finops_servico4 em finops
# ✅ Criado: finops_servico5 em finops
# ✅ Criado: finops_servico6 em finops
# ✅ Criado: finops_servico7 em finops
# ✅ Criado: finops_servico8 em finops
# ✅ Criado: finops_servico9 em finops
# ✅ Criado: finops_servico10 em finops
# ✅ Criado: finops_servico11 em finops
# ✅ Criado: finops_servico12 em finops
# ✅ Criado: finops_servico13 em finops
# ✅ Criado: finops_servico14 em finops
# ✅ Criado: finops_servico15 em finops
# ✅ Criado: finops_servico16 em finops
# ✅ Criado: finops_servico17 em finops
# ✅ Criado: finops_servico18 em finops
# ✅ Criado: finops_servico19 em finops
# ✅ Criado: finops_servico20 em finops
# ✅ Criado: pix_servico1 em pix
# ✅ Criado: pix_servico2 em pix
# ✅ Criado: pix_servico3 em pix
# ✅ Criado: pix_servico4 em pix
# ✅ Criado: pix_servico5 em pix
# ✅ Criado: pix_servico6 em pix
# ✅ Criado: pix_servico7 em pix
# ✅ Criado: pix_servico8 em pix
# ✅ Criado: pix_servico9 em pix
# ✅ Criado: pix_servico10 em pix
# ✅ Criado: pix_servico11 em pix
# ✅ Criado: pix_servico12 em pix
# ✅ Criado: pix_servico13 em pix
# ✅ Criado: pix_servico14 em pix
# ✅ Criado: pix_servico15 em pix
# ✅ Criado: pix_servico16 em pix
# ✅ Criado: pix_servico17 em pix
# ✅ Criado: pix_servico18 em pix
# ✅ Criado: pix_servico19 em pix
# ✅ Criado: pix_servico20 em pix
# ✅ Criado: ti_servico1 em ti
# ✅ Criado: ti_servico2 em ti
# ✅ Criado: ti_servico3 em ti
# ✅ Criado: ti_servico4 em ti
# ✅ Criado: ti_servico5 em ti
# ✅ Criado: ti_servico6 em ti
# ✅ Criado: ti_servico7 em ti
# ✅ Criado: ti_servico8 em ti
# ✅ Criado: ti_servico9 em ti
# ✅ Criado: ti_servico10 em ti
# ✅ Criado: ti_servico11 em ti
# ✅ Criado: ti_servico12 em ti
# ✅ Criado: ti_servico13 em ti
# ✅ Criado: ti_servico14 em ti
# ✅ Criado: ti_servico15 em ti
# ✅ Criado: ti_servico16 em ti
# ✅ Criado: ti_servico17 em ti
# ✅ Criado: ti_servico18 em ti
# ✅ Criado: ti_servico19 em ti
# ✅ Criado: ti_servico20 em ti

# %%
servicos_existentes = ler_scripts_dos_jobs(jobs)

# %%
def analisar_codigo_por_ia(result, codigo):
    return result[codigo]

# %%
def analisar_servicos_com_ia(servicos_existentes):
    resultados = []
    with open("out.json", "r") as fp:
        result = json.load(fp)
        for servico in servicos_existentes:
            area = servico['area']
            nome_servico = servico['nome_servico']
            codigo = servico['codigo']
            analise = analisar_codigo_por_ia(result, codigo)
            
            script_name = f"{nome_servico}_temp.py"
            new_key = f"{area}/{script_name}"
            bucket = 'costs-data-123'
            
            s3.put_object(
                Bucket=bucket,
                Key=new_key,
                Body=analise["codigo_sugestao"].encode("utf-8")
            )
            
            new_script_location = f"s3://{bucket}/{new_key}"
            
            resultado = {
                "area": area,
                "nome_servico": nome_servico,
                "codigo": codigo,
                "problema_log": analise["problema_log"],
                "quantidade_problemas_log": int(analise["quantidade_problemas_log"]),
                "codigo_sugestao": analise["codigo_sugestao"],
                "new_script_location": new_script_location
            }
            resultados.append(resultado)
    return resultados

# %%
servicos_analisados = analisar_servicos_com_ia(servicos_existentes)

for s in servicos_analisados:
    print(f"{s['area']}/{s['nome_servico']} -> problema_log: {s['problema_log']} ({s['quantidade_problemas_log']})")
    print(f"Nova versão salva em: {s['new_script_location']}")
    print("--------")
# Out:
# cartoes/servico1 -> problema_log: False (5)
# Nova versão salva em: s3://costs-data-123/cartoes/servico1_temp.py
# --------
# cartoes/servico10 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/cartoes/servico10_temp.py
# --------
# cartoes/servico11 -> problema_log: False (4)
# Nova versão salva em: s3://costs-data-123/cartoes/servico11_temp.py
# --------
# cartoes/servico12 -> problema_log: False (6)
# Nova versão salva em: s3://costs-data-123/cartoes/servico12_temp.py
# --------
# cartoes/servico13 -> problema_log: True (6)
# Nova versão salva em: s3://costs-data-123/cartoes/servico13_temp.py
# --------
# cartoes/servico14 -> problema_log: False (3)
# Nova versão salva em: s3://costs-data-123/cartoes/servico14_temp.py
# --------
# cartoes/servico15 -> problema_log: False (6)
# Nova versão salva em: s3://costs-data-123/cartoes/servico15_temp.py
# --------
# cartoes/servico16 -> problema_log: True (6)
# Nova versão salva em: s3://costs-data-123/cartoes/servico16_temp.py
# --------
# cartoes/servico17 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/cartoes/servico17_temp.py
# --------
# cartoes/servico18 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/cartoes/servico18_temp.py
# --------
# cartoes/servico19 -> problema_log: False (6)
# Nova versão salva em: s3://costs-data-123/cartoes/servico19_temp.py
# --------
# cartoes/servico2 -> problema_log: True (5)
# Nova versão salva em: s3://costs-data-123/cartoes/servico2_temp.py
# --------
# cartoes/servico20 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/cartoes/servico20_temp.py
# --------
# cartoes/servico3 -> problema_log: False (6)
# Nova versão salva em: s3://costs-data-123/cartoes/servico3_temp.py
# --------
# cartoes/servico4 -> problema_log: False (5)
# Nova versão salva em: s3://costs-data-123/cartoes/servico4_temp.py
# --------
# cartoes/servico5 -> problema_log: True (3)
# Nova versão salva em: s3://costs-data-123/cartoes/servico5_temp.py
# --------
# cartoes/servico6 -> problema_log: False (3)
# Nova versão salva em: s3://costs-data-123/cartoes/servico6_temp.py
# --------
# cartoes/servico7 -> problema_log: False (3)
# Nova versão salva em: s3://costs-data-123/cartoes/servico7_temp.py
# --------
# cartoes/servico8 -> problema_log: False (4)
# Nova versão salva em: s3://costs-data-123/cartoes/servico8_temp.py
# --------
# cartoes/servico9 -> problema_log: True (3)
# Nova versão salva em: s3://costs-data-123/cartoes/servico9_temp.py
# --------
# financas/servico1 -> problema_log: False (5)
# Nova versão salva em: s3://costs-data-123/financas/servico1_temp.py
# --------
# financas/servico10 -> problema_log: False (3)
# Nova versão salva em: s3://costs-data-123/financas/servico10_temp.py
# --------
# financas/servico11 -> problema_log: False (3)
# Nova versão salva em: s3://costs-data-123/financas/servico11_temp.py
# --------
# financas/servico12 -> problema_log: False (6)
# Nova versão salva em: s3://costs-data-123/financas/servico12_temp.py
# --------
# financas/servico13 -> problema_log: True (3)
# Nova versão salva em: s3://costs-data-123/financas/servico13_temp.py
# --------
# financas/servico14 -> problema_log: True (3)
# Nova versão salva em: s3://costs-data-123/financas/servico14_temp.py
# --------
# financas/servico15 -> problema_log: False (3)
# Nova versão salva em: s3://costs-data-123/financas/servico15_temp.py
# --------
# financas/servico16 -> problema_log: True (4)
# Nova versão salva em: s3://costs-data-123/financas/servico16_temp.py
# --------
# financas/servico17 -> problema_log: False (6)
# Nova versão salva em: s3://costs-data-123/financas/servico17_temp.py
# --------
# financas/servico18 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/financas/servico18_temp.py
# --------
# financas/servico19 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/financas/servico19_temp.py
# --------
# financas/servico2 -> problema_log: True (3)
# Nova versão salva em: s3://costs-data-123/financas/servico2_temp.py
# --------
# financas/servico20 -> problema_log: False (4)
# Nova versão salva em: s3://costs-data-123/financas/servico20_temp.py
# --------
# financas/servico3 -> problema_log: False (3)
# Nova versão salva em: s3://costs-data-123/financas/servico3_temp.py
# --------
# financas/servico4 -> problema_log: False (6)
# Nova versão salva em: s3://costs-data-123/financas/servico4_temp.py
# --------
# financas/servico5 -> problema_log: True (4)
# Nova versão salva em: s3://costs-data-123/financas/servico5_temp.py
# --------
# financas/servico6 -> problema_log: True (5)
# Nova versão salva em: s3://costs-data-123/financas/servico6_temp.py
# --------
# financas/servico7 -> problema_log: False (4)
# Nova versão salva em: s3://costs-data-123/financas/servico7_temp.py
# --------
# financas/servico8 -> problema_log: True (3)
# Nova versão salva em: s3://costs-data-123/financas/servico8_temp.py
# --------
# financas/servico9 -> problema_log: False (5)
# Nova versão salva em: s3://costs-data-123/financas/servico9_temp.py
# --------
# finops/servico1 -> problema_log: False (3)
# Nova versão salva em: s3://costs-data-123/finops/servico1_temp.py
# --------
# finops/servico10 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/finops/servico10_temp.py
# --------
# finops/servico11 -> problema_log: True (5)
# Nova versão salva em: s3://costs-data-123/finops/servico11_temp.py
# --------
# finops/servico12 -> problema_log: True (5)
# Nova versão salva em: s3://costs-data-123/finops/servico12_temp.py
# --------
# finops/servico13 -> problema_log: True (4)
# Nova versão salva em: s3://costs-data-123/finops/servico13_temp.py
# --------
# finops/servico14 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/finops/servico14_temp.py
# --------
# finops/servico15 -> problema_log: True (6)
# Nova versão salva em: s3://costs-data-123/finops/servico15_temp.py
# --------
# finops/servico16 -> problema_log: False (6)
# Nova versão salva em: s3://costs-data-123/finops/servico16_temp.py
# --------
# finops/servico17 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/finops/servico17_temp.py
# --------
# finops/servico18 -> problema_log: True (4)
# Nova versão salva em: s3://costs-data-123/finops/servico18_temp.py
# --------
# finops/servico19 -> problema_log: False (3)
# Nova versão salva em: s3://costs-data-123/finops/servico19_temp.py
# --------
# finops/servico2 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/finops/servico2_temp.py
# --------
# finops/servico20 -> problema_log: False (5)
# Nova versão salva em: s3://costs-data-123/finops/servico20_temp.py
# --------
# finops/servico3 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/finops/servico3_temp.py
# --------
# finops/servico4 -> problema_log: False (6)
# Nova versão salva em: s3://costs-data-123/finops/servico4_temp.py
# --------
# finops/servico5 -> problema_log: False (5)
# Nova versão salva em: s3://costs-data-123/finops/servico5_temp.py
# --------
# finops/servico6 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/finops/servico6_temp.py
# --------
# finops/servico7 -> problema_log: True (3)
# Nova versão salva em: s3://costs-data-123/finops/servico7_temp.py
# --------
# finops/servico8 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/finops/servico8_temp.py
# --------
# finops/servico9 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/finops/servico9_temp.py
# --------
# pix/servico1 -> problema_log: True (2)
# Nova versão salva em: s3://costs-data-123/pix/servico1_temp.py
# --------
# pix/servico10 -> problema_log: True (3)
# Nova versão salva em: s3://costs-data-123/pix/servico10_temp.py
# --------
# pix/servico11 -> problema_log: False (3)
# Nova versão salva em: s3://costs-data-123/pix/servico11_temp.py
# --------
# pix/servico12 -> problema_log: False (5)
# Nova versão salva em: s3://costs-data-123/pix/servico12_temp.py
# --------
# pix/servico13 -> problema_log: False (6)
# Nova versão salva em: s3://costs-data-123/pix/servico13_temp.py
# --------
# pix/servico14 -> problema_log: False (4)
# Nova versão salva em: s3://costs-data-123/pix/servico14_temp.py
# --------
# pix/servico15 -> problema_log: True (3)
# Nova versão salva em: s3://costs-data-123/pix/servico15_temp.py
# --------
# pix/servico16 -> problema_log: True (6)
# Nova versão salva em: s3://costs-data-123/pix/servico16_temp.py
# --------
# pix/servico17 -> problema_log: True (6)
# Nova versão salva em: s3://costs-data-123/pix/servico17_temp.py
# --------
# pix/servico18 -> problema_log: True (6)
# Nova versão salva em: s3://costs-data-123/pix/servico18_temp.py
# --------
# pix/servico19 -> problema_log: True (3)
# Nova versão salva em: s3://costs-data-123/pix/servico19_temp.py
# --------
# pix/servico2 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/pix/servico2_temp.py
# --------
# pix/servico20 -> problema_log: False (3)
# Nova versão salva em: s3://costs-data-123/pix/servico20_temp.py
# --------
# pix/servico3 -> problema_log: True (4)
# Nova versão salva em: s3://costs-data-123/pix/servico3_temp.py
# --------
# pix/servico4 -> problema_log: True (5)
# Nova versão salva em: s3://costs-data-123/pix/servico4_temp.py
# --------
# pix/servico5 -> problema_log: True (5)
# Nova versão salva em: s3://costs-data-123/pix/servico5_temp.py
# --------
# pix/servico6 -> problema_log: False (5)
# Nova versão salva em: s3://costs-data-123/pix/servico6_temp.py
# --------
# pix/servico7 -> problema_log: True (3)
# Nova versão salva em: s3://costs-data-123/pix/servico7_temp.py
# --------
# pix/servico8 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/pix/servico8_temp.py
# --------
# pix/servico9 -> problema_log: False (3)
# Nova versão salva em: s3://costs-data-123/pix/servico9_temp.py
# --------
# ti/servico1 -> problema_log: True (5)
# Nova versão salva em: s3://costs-data-123/ti/servico1_temp.py
# --------
# ti/servico10 -> problema_log: False (6)
# Nova versão salva em: s3://costs-data-123/ti/servico10_temp.py
# --------
# ti/servico11 -> problema_log: True (4)
# Nova versão salva em: s3://costs-data-123/ti/servico11_temp.py
# --------
# ti/servico12 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/ti/servico12_temp.py
# --------
# ti/servico13 -> problema_log: False (5)
# Nova versão salva em: s3://costs-data-123/ti/servico13_temp.py
# --------
# ti/servico14 -> problema_log: False (3)
# Nova versão salva em: s3://costs-data-123/ti/servico14_temp.py
# --------
# ti/servico15 -> problema_log: False (3)
# Nova versão salva em: s3://costs-data-123/ti/servico15_temp.py
# --------
# ti/servico16 -> problema_log: True (2)
# Nova versão salva em: s3://costs-data-123/ti/servico16_temp.py
# --------
# ti/servico17 -> problema_log: False (5)
# Nova versão salva em: s3://costs-data-123/ti/servico17_temp.py
# --------
# ti/servico18 -> problema_log: False (3)
# Nova versão salva em: s3://costs-data-123/ti/servico18_temp.py
# --------
# ti/servico19 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/ti/servico19_temp.py
# --------
# ti/servico2 -> problema_log: True (4)
# Nova versão salva em: s3://costs-data-123/ti/servico2_temp.py
# --------
# ti/servico20 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/ti/servico20_temp.py
# --------
# ti/servico3 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/ti/servico3_temp.py
# --------
# ti/servico4 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/ti/servico4_temp.py
# --------
# ti/servico5 -> problema_log: False (3)
# Nova versão salva em: s3://costs-data-123/ti/servico5_temp.py
# --------
# ti/servico6 -> problema_log: False (3)
# Nova versão salva em: s3://costs-data-123/ti/servico6_temp.py
# --------
# ti/servico7 -> problema_log: False (3)
# Nova versão salva em: s3://costs-data-123/ti/servico7_temp.py
# --------
# ti/servico8 -> problema_log: False (6)
# Nova versão salva em: s3://costs-data-123/ti/servico8_temp.py
# --------
# ti/servico9 -> problema_log: False (2)
# Nova versão salva em: s3://costs-data-123/ti/servico9_temp.py
# --------

# %%
len(servicos_analisados)
# Out:
# 100

# %%
def salvar_tabela_analitica_athena(servicos_analizados, bucket, database, nome_tabela="tb_sor_servicos_analitico"):
    df = pd.DataFrame(servicos_analizados)
    indicadores = ['problema_log', 'quantidade_problemas_log']
    df_melted = df.melt(id_vars=['area', 'nome_servico'], 
                        value_vars=indicadores, 
                        var_name='indicador', 
                        value_name='valor')
    df_melted['valor'] = df_melted['valor'].apply(lambda x: float(x) if isinstance(x, (int, float)) else 1.0 if x is True else 0.0)
    
    caminho_s3 = f"s3://{bucket}/athena/servicos_analitico/tb_sor_servicos_analitico"
    wr.s3.to_parquet(
        df=df_melted,
        path=caminho_s3,
        dataset=True,
        database=database,
        table=nome_tabela,
        mode="overwrite"
    )
    print(f"✅ Tabela '{nome_tabela}' criada no Athena (DB: {database}) com {len(df_melted)} registros.")

# %%
salvar_tabela_analitica_athena(
    servicos_analizados=servicos_analisados,
    bucket='costs-data-123',
    database='workspace'
)
# Out:
# 2025-06-08 18:02:22,065	WARNING services.py:2070 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 8312041472 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=10.24gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2025-06-08 18:02:22,214	INFO worker.py:1852 -- Started a local Ray instance.
# ✅ Tabela 'tb_sor_servicos_analitico' criada no Athena (DB: workspace) com 200 registros.

# %%
query = f"SELECT * FROM tb_sor_servicos_analitico"
    
df = wr.athena.read_sql_query(
    sql=query,
    database='workspace'
)

print("📊 Dados lidos da tabela:")
display(df)
# Out:
# 📊 Dados lidos da tabela:
#         area nome_servico                 indicador  valor
# 0    cartoes     servico1              problema_log    0.0
# 1    cartoes    servico10              problema_log    0.0
# 2    cartoes    servico11              problema_log    0.0
# 3    cartoes    servico12              problema_log    0.0
# 4    cartoes    servico13              problema_log    1.0
# ..       ...          ...                       ...    ...
# 195       ti     servico5  quantidade_problemas_log    3.0
# 196       ti     servico6  quantidade_problemas_log    3.0
# 197       ti     servico7  quantidade_problemas_log    3.0
# 198       ti     servico8  quantidade_problemas_log    6.0
# 199       ti     servico9  quantidade_problemas_log    2.0
#
# [200 rows x 4 columns]
